# %% [markdown]
# <a href="https://colab.research.google.com/github/easywater4528/python-matplot/blob/main/2025319856_%EC%9D%B4%EC%A7%80%EC%88%98_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 금일 사용할 패키지

import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np

## 한글 사용을 위한 페키지##
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
plt.rc('font', family='NanumBarunGothic')
mpl.rcParams['axes.unicode_minus'] = False
############################
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %% [markdown]
# #코드 실행해보기
#
# - 코드들을 실행해보면서 직접 출력해 봅시다.

# %%
plt.title("그래프 제목")
plt.plot([1,10,100,1000],'rs--')

plt.xlabel("엑스축")
plt.ylabel("와이축")
plt.show()

# %%
sales = [25, 35, 15]
menu = ['아메리카노','카페라테','마키아또']

plt.title("Bar Chart")
plt.bar(menu, sales)

plt.xlabel("메뉴")
plt.ylabel("판매수")
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels)
plt.show()

# %%
x = np.random.randn(100000)
# 가우시안 표준 정규 분포 난수 생성
plt.title("Histogram")
plt.hist(x, bins=100)
# 구간 개수 지정
plt.show()

# %%
X = np.random.randn(1000)
Y = np.random.randn(1000)
plt.title("Scatter Plot")
plt.scatter(X, Y)
plt.show()

# %%
data = np.random.randn(1000)
plt.boxplot( data )
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
axes[0, 0].pie(ratio, labels=labels, colors=colors)
axes[0, 0].set_title("data 1")

sales = [25, 35, 15]
menu = ['아메리카노', '카페라테', '마키아또']
axes[0, 1].barh(menu, sales)
axes[0, 1].set_title("data 2")

x = np.random.randn(1000)
axes[1, 0].hist(x, bins=100)
axes[1, 0].set_title("data 3")

data1 = np.random.normal(0, 2.0, 1000)
data2 = np.random.normal(-3.0, 1.5, 1000)
data3 = np.random.normal(1.2, 1.5, 1000)
axes[1, 1].boxplot([data1, data2, data3])
axes[1, 1].set_title("data 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# #문제 1
# - 주식 데이터를 사용하여 실습을 진행해보도록 하겠습니다.
# - label과 ratio는 주식시장에서 개인, 기관, 외인이 얼마만큼 비중을 차지하는지 나타냅니다.
# - 아래 정답 예시와 출력이 같아지도록 "빈칸"으로 표시된 곳을 적절히 채워보세요.

# %%
date = [1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217,1218,1219,1220,1221,1222,1223,1224,1225,1226,1227,1228,1229,1230,1231]
stock_data = [10000, 11200, 12000, 13000, 14300, 11000, 9000, 8500, 8700, 8600, 8900, 9100, 9300, 10000, 11000,10800,12000, 11900,11800,11900,11800,12000,12100,12200,12300,12500,13100,13200,13200,13300,18400]
label = ['Retail','Institutional','Foreigner']
ratio = [0.6,0.3,0.1]


# x: 날짜 y: 종가 선그래프
plt.plot(date,stock_data)
plt.title("Closing price 12/01~12/31")
plt.show()

#종가의 히스토그램 분포
plt.hist(stock_data)
plt.title("Closing price distribution")
plt.show()

#주식 시장의 개인,기관,외인 파이 그래프
plt.pie(ratio, labels = label)
plt.title("Market ratio")
plt.show()

#종가에 대한 박스 그래프
plt.boxplot(stock_data)
plt.title("Closing price outlier")
plt.show()

# %% [markdown]
# ##정답 예시
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Colab data
# - Colab에서는 몇 개의 기본 데이터를 'sample_data/'폴더에서 제공하고 있습니다.
#
# - 좌측의 Colab 메뉴에서 폴더 모양을 선택하시면 아래와 같이 확인하실 수 있습니다.
#
# ![image.png](data:image/png;base64,...)
#
# - 필요에 따라 자신이 원하는 데이터를 업로드하여 사용하실 수도 있습니다. 다만 이 경우 세션이 만료될 때 업로드한 자료도 사라지기에 주의하시기 바랍니다.

# %% [markdown]
# # California housing data
# - 저희는 그중 "California_housing_train" 데이터를 사용하여 실습을 해보도록 하겠습니다.
# - California housing 데이터는 1990년 캘리포니아 인구조사 데이터입니다.
# - 데이터의 각 행은 한 블록의(주택의 그룹) 특징을 담고 있습니다.
#
# 　　　　　- 경도(longitude)
#
# 　　　　　- 위도(latitude)
#
# 　　　　　- 주택 나이(블록 중앙 값)(housing_median_age)
#
# 　　　　　- 전체 방 수(total_rooms)
#
# 　　　　　- 전체 침실 수(total_bedrooms)
#
# 　　　　　- 인구(population)
#
# 　　　　　- 세대(households)
#
# 　　　　　- 소득(블록 중앙 값)(median_income)
#
# 　　　　　- 주택 가치(블록 중앙 값)(median_house_value)
#
# 　　　　　- 바다 접근도(ocean_proximity)

# %% [markdown]
# #California housing data 분석 및 코드 예시
#
# - 위에서 설명한 캘리포니아 데이터 프레임을 불러오고 분석해봅시다.
# - 아래의 코드 예시를 실행시켜보고 출력을 확인해봅시다.

# %%
data_path = 'sample_data/california_housing_train.csv'
df = pd.read_csv(data_path)
print(df.describe())

# 주택 나이에 대한 히스토그램 분포
plt.hist(df['housing_median_age'])
plt.title("hist_housing_median_age")
plt.show()
print()

# x를 경도, y를 위도로 하는 선 그래프
plt.title("plot_x_longitude_y_latitude")
plt.plot(df['longitude'],df['latitude'])
plt.show()
print()

# 주택 가치에 대한 박스 그래프
plt.title("box_median_house_value")
plt.boxplot(df['median_house_value'])
plt.show()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# #문제2
# - 'median_house_value'를 기준으로 데이터프레임을 오름차순 정렬해보고 그래프를 출력하세요.
#
#
#
# - subplots을 사용해 3개의 그래프들을 묶어 3개의 행을 가진 형태로 출력하셔야합니다.
#         그래프 1
#         그래프 2
#         그래프 3
#
#
# - (1,1) 위치에는 'median_house_value'에 대한 히스토그램을 그려서 어느 가격대의 집에 사람들이 많이 사는지 확인해보세요.
#
#
# - (2,1) 위치에는 'median_house_value'를 x축으로, y축에는 'median_income'을 넣어서 plot해보고 서로의 관계를 생각해보세요. 그리고, 가장 많은 사람이 분포할 소득 범위에 대해서 예측해봅시다.
#
#
# - (3,1) 위치에는 'median_income'을 통해 히스토그램을 그려서 자신이 예측한 가장 많은 사람이 분포하는 소득 범위와 일치하는지 확인해보세요

# %%
# 'median house value'를 기준으로 sort
df = df.sort_values (by='median_house_value', axis=0)

# (1,1) 'median house value' 히스토그램 출력
fig, axes = plt.subplots(3,1)
axes[0].hist(df['median_house_value'])

# (2,1) x 'median house value', y 'median_income'  선그래프 출력
axes[1].plot(df['median_house_value'], df['median_income'])
# (3,1) 'median_income' 히스토그램 출력
axes[2].hist(df['median_income'])

plt.tight_layout()
plt.show()

# %% [markdown]
# #정답 예시
#
# ![다운로드.png](data:image/png;base64,...)

# %% [markdown]
# # 문제 3
#
# - 앞서 확인한 것처럼, California housing data에는 위도, 경도 정보가 주어져 있습니다.
# - 하나의 블록의 위도와 경도를 사용해 한 "점"으로 나타낸다면 (x,y) 좌표로 출력을 할 수 있습니다.
# - Scatter Plot을 사용하여 x를 longitude로, y를 latitude로 해서 어느 곳에 주택들이 분포하는지 확인해봅시다

# %%
plt.scatter(df['longitude'], df['latitude'])
plt.show()

# %% [markdown]
# #정답 예시
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #문제3(Cont.)
#
# - plt에는 colorbar()라는 함수가 존재하는데, 이를 사용해 어떤 색이 어떤 값을 나타내는지 쉽게 볼 수 있습니다.
# - scatter에 color를 지정하고 colorbar 함수가 어떤 역할을 하는지 알아 봅시다.
# - scatter plot에서 color는 "colors = " 대신 "c = "을 사용하고, 값이 들어갈 수 있습니다.
# - 값을 사용하게 될 경우 각 점에 대한 가중치 값 표현이 가능합니다.
# - 아래의 예시를 직접 출력해보시기 바랍니다.

# %%
# X 위치
loc_x = [0, 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9]
# Y 위치
loc_y = [18, 19.1, 19.3, 18.7, 17.2, 14.8, 11.5, 7.3, 2.3, -3.7, -10.5]
# Y 방향 속도
velocity_y = [5.2, 2.3, -0.7, -3.6, -6.6, -9.5, -12.4, -15.4, -18.3, -21.3, -24.2]

plt.scatter(loc_x, loc_y, c = velocity_y)
plt.title("Projectile motion")
plt.xlabel("X_location")
plt.ylabel("Y_location")
plt.colorbar()
plt.show()

# %% [markdown]
# #문제3(Cont.)
#
# - 앞서 실행해보신 것처럼, Color bar를 사용하여 어떤 색이 어떤 값을 표현하는지 그라데이션으로 명확히 보실 수 있습니다.
# - 이를 사용해 문제 3의 scatter plot에 주택 가치를 색으로 주어 colorbar를 출력해서 어느 지역에 높은 집 값이 분포하는지 알아봅시다.

# %%
# 문제 3에 colorbar를 적용해 출력해보는 코드를 여기에 작성하세요.

plt.scatter(df['longitude'], df['latitude'], c=df['median_house_value'])
plt.colorbar()
plt.show()

# %% [markdown]
# #정답 예시
#
# ![image.png](data:image/png;base64,...)
